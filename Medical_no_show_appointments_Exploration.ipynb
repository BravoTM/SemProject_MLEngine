# %% [markdown]
# <a href="https://colab.research.google.com/github/BWahot/SemProject_MLEngine/blob/main/Medical_no_show_appointments_Exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@ number of rows and columns
import pandas as pd
df = pd.read_csv('KaggleV2-May-2016.csv')
print(f"Rows: {df.shape[0]}, Columns: {df.shape[1]}")
# 110527 rows X 14 columns
# Out:
# Rows: 110527, Columns: 14

# %%
#@ Datatypes
df.dtypes
# integers example (sms_received,diabetes)
# floating-point deciaml numbers example (2.987)
# strings example (gender(F OR M))
# Out:
# PatientId         float64
# AppointmentID       int64
# Gender             object
# ScheduledDay       object
# AppointmentDay     object
# Age                 int64
# Neighbourhood      object
# Scholarship         int64
# Hipertension        int64
# Diabetes            int64
# Alcoholism          int64
# Handcap             int64
# SMS_received        int64
# No-show            object
# dtype: object

# %%
#@ Is dataset complete
is_complete = df.isnull().sum().sum() == 0
print(f"Is the dataset complete (no missing values)? {is_complete}")
# Out:
# Is the dataset complete (no missing values)? True
